# %% [markdown]
# # 1.	Remote Load:

# %% [raw]
#  Load a dataset directly from a URL (Github) and use .info() to identify which columns have the most missing values.

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ywchiu/riii/refs/heads/master/data/house-prices.csv')

# %%
data=pd.read_csv('http://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/doc/data/titanic.csv')

# %%
df
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Home          128 non-null    int64
#  1   Price         128 non-null    int64
#  2   SqFt          128 non-null    int64
#  3   Bedrooms      128 non-null    int64
#  4   Bathrooms     128 non-null    int64
#  5   Offers        128 non-null    int64
#  6   Brick         128 non-null    object
#  7   Neighborhood  128 non-null    object
# dtypes: int64(6), object(2)
# memory usage: 8.1+ KB

# %%
df.isnull().sum()
# Out:
# Home            0
# Price           0
# SqFt            0
# Bedrooms        0
# Bathrooms       0
# Offers          0
# Brick           0
# Neighborhood    0
# dtype: int64

# %% [markdown]
# # 2.	Stat Analysis:

# %% [raw]
#  Use .describe(include='all') on the Titanic data. What is the most common "Embarked" port?

# %%
# S port is most common embarked port

# %% [markdown]
# # 3.	Memory Check:

# %% [raw]
#  Compare the memory usage of your DataFrame before and after deleting a column using data.info().r

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data=data.drop(columns=['Parch'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %% [markdown]
# # 4.	Unique Insights:

# %% [raw]
#  Find how many unique values exist in the "Pclass" column using .unique() or .nunique().

# %%
data['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# # 5.	Exporting:

# %% [raw]
# Create a subset of passengers who survived and save it as a new CSV called survivors.csv.

# %%
surviver=data[data['Survived']==1]

# %%
surviver.to_csv('survivors.csv')

# %% [markdown]
# # 6.	Complex Filter:

# %% [raw]
# Extract passengers who were in 1st Class AND were Female.

# %%
data[(data['Pclass']==1) & (data['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                             Bonnell, Miss Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 7.	Fare Outliers:

# %% [raw]
#  Find passengers who paid a fare in the top 5% of all ticket prices

# %%
top=data['Fare'].quantile(0.95)
top
# Out:
# np.float64(112.07915)

# %%
data[data['Fare']>top]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# 390          391         1       1
# 393          394         1       1
# ...

# %% [markdown]
# # 8.	Column Operations:

# %% [raw]
# Create a new column called "Is_Adult" which is True if Age $\ge$ 18 and False otherwise.

# %%
data['Is_Adult']=data['Age']>=18

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 9.	String Search:

# %% [raw]
# Filter the "Name" column to find all passengers with the title "Master" (common in NLP text filtering).

# %%
data['Name'].str.contains('Master')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %% [markdown]
# # 10.	Index Reset:

# %% [raw]
# Slice the first 10 rows and then use .reset_index(drop=True) to make the index start from 0 again.

# %%
data[:10].reset_index(drop=True)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # 11.	Smart Fill:

# %% [raw]
#  Fill the missing "Age" values not with a single number, but with the median age of the entire dataset.

# %%
median=data['Age'].mean
data['Age']=data['Age'].fillna(median)

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 12.	Categorical Swap:

# %% [raw]
#  Change "male" to 1 and "female" to 0 in the "Sex" column using .map() or .replace().

# %%
def gender(x):
    if x=='male':
        return 1
    else:
        return 0

# %%
data['Sex']=data['Sex'].apply(gender)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  \
# 0                              Braund, Mr. Owen Harris    1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2                                Heikkinen, Miss Laina    0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4                             Allen, Mr. William Henry    1
# ..                                                 ...  ...
# 886                              Montvila, Rev. Juozas    1
# ...

# %% [markdown]
# # 13.	Null Drop:

# %% [raw]
#  Drop all rows where "Cabin" is missing. How many rows are left?

# %%
data['Cabin'].isnull().sum()
# Out:
# np.int64(687)

# %%
data=data[data['Cabin'].notnull()]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                      Sandstrom, Miss Marguerite Rut  female   4.0      1
# 11                             Bonnell, Miss Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 14.	Sorting:

# %% [raw]
#  Sort the DataFrame by "Fare" (highest first) and then by "Age" (youngest first).

# %%
sorted_data1=data.sort_values(by='Fare',ascending=False)

# %%
sorted_data1
# Out:
#      PassengerId  Survived  Pclass  \
# 679          680         1       1
# 737          738         1       1
# 88            89         1       1
# 341          342         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 715          716         0       3
# 872          873         0       1
# 806          807         0       1
# 263          264         0       1
# 815          816         0       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 679          Cardeza, Mr. Thomas Drake Martinez    male  36.0      0      1
# 737                      Lesurer, Mr. Gustave J    male  35.0      0      0
# 88                    Fortune, Miss Mabel Helen  female  23.0      3      2
# 341               Fortune, Miss Alice Elizabeth  female  24.0      3      2
# 27               Fortune, Mr. Charles Alexander    male  19.0      3      2
# ..                                          ...     ...   ...    ...    ...
# ...

# %%
sorted_data2=data.sort_values(by='Age')

# %%
sorted_data2
# Out:
#      PassengerId  Survived  Pclass  \
# 305          306         1       1
# 183          184         1       2
# 297          298         0       1
# 205          206         0       3
# 340          341         1       2
# ..           ...       ...     ...
# 740          741         1       1
# 776          777         0       3
# 815          816         0       1
# 839          840         1       1
# 849          850         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 305                 Allison, Master Hudson Trevor    male  0.92      1      2
# 183                      Becker, Master Richard F    male  1.00      2      1
# 297                   Allison, Miss Helen Loraine  female  2.00      1      2
# 205                     Strom, Miss Telma Matilda  female  2.00      0      1
# 340                 Navratil, Master Edmond Roger    male  2.00      1      1
# ...

# %% [markdown]
# # 16.	Group Analysis:

# %% [raw]
#  Group the data by "Pclass" and calculate the mean fare for each class.

# %%
data.groupby(by='Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# # 17.	Survival Rates:

# %% [raw]
#  Use .groupby() to find the percentage of people who survived in each "Sex" category.

# %%
Male_per=data['Sex']['male'].where('Survived'==1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 Male_per=data['Sex']['male'].where('Survived'==1)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
# ...

# %%
data.groupby(by='Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# # 18.	Pivot Tables:

# %% [raw]
# Research .pivot_table(). Create a table showing the number of survivors, broken down by both "Pclass" and "Sex".

# %%
data.pivot_table(
    index='Pclass',
    columns='Sex',
    values='Survived',
    aggfunc='sum'
)
# Out:
# Sex     female  male
# Pclass
# 1           91    45
# 2           70    17
# 3           72    47

# %% [markdown]
# # 20.	Time Series (Preview):

# %% [raw]
#  If a column has dates, convert it to datetime format using pd.to_datetime() and extract the "Month".

# %% [raw]
# ------>>>> data['Date'] = pd.to_datetime(data['Date'])

# %% [raw]
# data['Month']=data['Date'].dt.month
