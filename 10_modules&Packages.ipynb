# %%
def summation(*args):
    result=0
    for i in args:
        result=result+i
    return result

# %%
summation(2,3,6,7,66,98,102,66)
# Out:
# 350

# %%
import func as func1
func1.multiplication(2,3,7,2)
# Out:
# 84

# %%
import func
func.summation(9,8,7,6,5,6,7,8,9)
# Out:
# 65

# %%
import module_1

# %%
module_1.square_evenodd(4)
# Out:
# (16, 'Even')

# %% [markdown]
# # ASSIGNMENT

# %% [raw]
# Q1 ) Import the platform module as plt and print your operating system name

# %%
import platform as plt
plt.android_ver()
# Out:
# AndroidVer(release='', api_level=0, manufacturer='', model='', device='', is_emulator=False)

# %%
plt.ios_ver()
# Out:
# IOSVersionInfo(system='', release='', model='', is_simulator=False)

# %%
plt.system()
# Out:
# 'Darwin'

# %%
plt.machine()
# Out:
# 'arm64'

# %%
plt.processor()
# Out:
# 'arm'

# %% [raw]
# Q2 ) Use from random import randint to generate a random number between 1 and 10.

# %%
from random import randint as inte
print(inte(1,99))
# Out:
# 79

# %% [raw]
# Q3 ) Use the os module to print all files in your current folder.

# %%
import os

# %%
os.listdir()
# Out:
# ['0_Practise.ipynb',
#  '.DS_Store',
#  'intro.txt',
#  '3_Tuple_Set_Dict.ipynb',
#  '4_if_for.ipynb',
#  '8_OOP2_Ass.ipynb',
#  '__pycache__',
#  '99_Personal_Library.ipynb',
#  '7_OOP_1.ipynb',
#  '5_Function.ipynb',
#  '2_List_Data_Structures1.ipynb',
#  '10_modules&Packages.ipynb',
#  '.ipynb_checkpoints',
#  '1_Basics.ipynb',
#  'module_1.py',
#  'func.py',
#  '9_FileHandling.ipynb',
#  '6_Iterator_Genrator.ipynb',
#  'intro,txt']

# %% [markdown]
# # Time Logger:

# %% [raw]
# Import the datetime module and create a function that returns the current time formatted for a log file

# %%
import datetime
t=datetime.datetime.now()
print(t)
# Out:
# 2026-05-09 17:42:29.929790

# %% [markdown]
# # Import pytz

# %%
from datetime import datetime
import pytz

tz=pytz.timezone('Asia/kolkata')
ct=datetime.now(tz)
print(ct)
# Out:
# 2026-05-09 18:00:25.735624+05:30

# %% [markdown]
# # Data Simulation:

# %% [raw]
# Use the random module to pick a random "sentiment" (Positive, Negative, Neutral) from a list.

# %%
sentiment=['Positive','Negative','Neutral']
import random
print(random.choice(sentiment))
# Out:
# Neutral

# %% [markdown]
# # System Paths:

# %% [raw]
#  Use os.path to check if a specific data file exists before trying to open it

# %%
import os
path='8_OOP2_Ass.ipynb'

if os.path.exists(path):
    print("File Exists")
else:
    print("File not exists")
# Out:
# File Exists

# %% [markdown]
# # String Constants:

# %% [raw]
# Import the string module and print all available punctuation marks (essential for cleaning NLP text).

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# # Remove punctuation from:

# %%
remove="Hello!!! Python, is awesome."

# %%
import string
result=[ ]
for i in remove:
    if i not in string.punctuation:
        result.append(i)
print(result)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'P', 'y', 't', 'h', 'o', 'n', ' ', 'i', 's', ' ', 'a', 'w', 'e', 's', 'o', 'm', 'e']

# %% [markdown]
# # 10.	JSON Handling

# %% [raw]
# Use the json module to convert a Python dictionary into a JSON string.

# %%
student={'name':'Vinayak',
        'marks':21}
import json
print(json.dumps(student))
# Out:
# {"name": "Vinayak", "marks": 21}

# %%
type(json.dumps(student))
# Out:
# str

# %%
type(student)
# Out:
# dict

# %% [markdown]
# # 11.	The dir() Function:

# %% [raw]
# Use dir() on the math module to see every function available inside it.

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %% [markdown]
# # 12.	Folder as Package:

# %% [raw]
#  Create a folder named mymodules. Inside it, put an empty __init__.py and a logic.py. Try importing from this folder.

# %%
from Mymodule import logic
logic.greeting()
# Out:
# Welcome to the logic of the code under my module

# %% [markdown]
# # 13.	Global vs Local:

# %% [raw]
#  Import a variable from a module, change it in your main script, and check if it changed in the original module.

# %%
from module_1 import value
value=10

# %%
print(value)
# Out:
# 10

# %% [markdown]
# # 14.	Reloading:

# %% [raw]
#  Research the importlib.reload() function. Why would you use this during active development

# %%
import importlib
import Mymodule
# this lib refreshes the module is any changes are made in it later

# %% [markdown]
# # 18.	Custom NLP Module:

# %% [raw]
#  Create a module text_utils.py with functions for remove_spaces() and word_count(). Use it to process a sentence.

# %%
import text_utils
a=input("Enter a sentence")
output=text_utils.remove_spaces(a)
text_utils.count_words(output)
# Out:
# Enter a sentence My name is vinayak waikar
# ('counting without spaces : ', 21)

# %% [markdown]
# # 20.	Dependency Check:

# %% [raw]
#  Write a script that tries to import a module and prints a custom error message if the module is not installed.

# %%
data=input("Enter module name to import")
try:
    __import__ (data)
    print("import successfull")
except ModuleNotFoundError:
    print("Module not installed ,Try with different module")
# Out:
# Enter module name to import numpy
# import successfull
