# %% [markdown]
# # Tuple

# %%
t=(1,2,"hello",True)

# %%
len(t)
# Out:
# 4

# %%
t.count(1)
# Out:
# 2

# %%
10 in t
# Out:
# False

# %%
t.index(2)
# Out:
# 1

# %%
z=(10,20,30,True,"Hello",35.5,50.6,True)

# %%
z[3]
# Out:
# True

# %%
type(z)
# Out:
# tuple

# %%
w=list(z)

# %%
type(z)
# Out:
# tuple

# %%
type(w)
# Out:
# list

# %% [markdown]
# # Typecasting

# %%
# How to convert tuple into list

# %%
T=(1,2,3,4,"Hello",True,10,20,30)

# %%
T=list(T)

# %%
T.remove(2)

# %%
T
# Out:
# [1, 3, 4, 'Hello', True, 10, 20, 30]

# %%
T=tuple(T)

# %%
type(T)
# Out:
# tuple

# %% [markdown]
# # SET

# %%
s={1,2,3,1,2,3,'Hello', True,False}

# %%
s
# Out:
# {1, 2, 3, False, 'Hello'}

# %%
s1={1,2,3,4,5}

# %%
s2={3,4,5,6,7}

# %%
 s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s2.difference(s1)
# Out:
# {6, 7}

# %%
s1.intersection(s2)
# Out:
# {3, 4, 5}

# %%
s1.remove(3)

# %%
s1
# Out:
# {1, 2, 4, 5}

# %%
s1.pop()
# Out:
# 1

# %%
s1.update("10")

# %%
s1
# Out:
# {'0', '1', 2, 4, 5}

# %% [markdown]
# # Dict

# %%
student={'Name':'Om' , 'Class':'10' , 'Mobile': 9168913342 , 'Add':'Pune'}

# %%
student
# Out:
# {'Name': 'Om', 'Class': '10', 'Mobile': 9168913342, 'Add': 'Pune'}

# %%
student.update({'Class':12 })

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Class', 'Mobile', 'Add', 'country'])

# %%
data={'Name':['Om','Sham','Ram','Geeta'],
     'Age':[20,50,23,55]}

# %%
data
# Out:
# {'Name': ['Om', 'Sham', 'Ram', 'Geeta'], 'Age': [20, 50, 23, 55]}

# %%
import pandas as pd

# %%
pd.DataFrame(data)
# Out:
#     Name  Age
# 0     Om   20
# 1   Sham   50
# 2    Ram   23
# 3  Geeta   55

# %%
data['Age']
# Out:
# [20, 50, 23, 55]

# %%
data['Age'][2]
# Out:
# 23

# %%
type(t)
# Out:
# tuple

# %%
t=list(t)

# %%
type(t)
# Out:
# list

# %%
t=[1,1,1,303,"Hello",2,4,]

# %%
t=tuple(t)

# %%
type(t)
# Out:
# tuple

# %%
t.count(1)
# Out:
# 3

# %%
s={10,20,30}

# %%
s.remove(20)

# %%
s
# Out:
# {10, 30}

# %%
type(t)
# Out:
# tuple

# %%
t=set(t)

# %%
type(t)
# Out:
# set

# %%
t
# Out:
# {1, 2, 303, 4, 'Hello'}

# %%
True in t
# Out:
# True

# %%
t=list(t)

# %%
t
# Out:
# [1, 2, 4, 303, 'Hello']

# %%
results = {'student': 'Om', 'scores': {'Maths': 90, 'Science': 85}}

# %%
results['scores']['Maths']
# Out:
# 90

# %%
d={i:i*i for i in range(1,3)}
d
# Out:
# {1: 1, 2: 4}
