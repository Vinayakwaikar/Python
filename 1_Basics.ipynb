# %% [markdown]
# # Data Types

# %%
a=int(5)

# %%
a
# Out:
# 5

# %%
5
# Out:
# 5

# %%
type(1+3j)
# Out:
# complex

# %%
5>1
# Out:
# True

# %%
type(5>1)
# Out:
# bool

# %% [markdown]
#  # Concatination

# %%
F_Name="Vinayak"

# %%
L_Name="Waikar_123"

# %%
Full_Name= F_Name+ " " +L_Name

# %%
Full_Name
# Out:
# 'Vinayak Waikar_123'

# %%
type(Full_Name)
# Out:
# str

# %% [markdown]
# # Type_Casting

# %%
num="123"

# %%
type(num)
# Out:
# str

# %%
num=123

# %%
type(num)
# Out:
# int

# %%
int(5.6)
# Out:
# 5

# %%
str(1)
# Out:
# '1'

# %%
round(3.45)
# Out:
# 3

# %%
round(4.5)
# Out:
# 4

# %%
a="123"

# %%
type(a)
# Out:
# str

# %%
a=int(a)

# %%
type(a)
# Out:
# int

# %%
Name="Vinayak"

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
Name
# Out:
# 'Vinayak'

# %%
Marks=56

# %%
Marks
# Out:
# 56

# %%
Print(Name+Marks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Print(Name+Marks)
#
# NameError: name 'Print' is not defined

# %%
Print(Name,Marks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Print(Name,Marks)
#
# NameError: name 'Print' is not defined

# %%
print(Name+Marks)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(Name+Marks)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(Name,Marks)
# Out:
# Vinayak 56

# %%
print(" My Name is " + Name + " And I Scored" ,Marks, "Marks")
# Out:
#  My Name is Vinayak And I Scored 56 Marks

# %% [markdown]
# # F formatting

# %%
Profession = "Software Devloper"
work="Write Code"
salary=40000

# %%
print(f'My Profession is {Profession} And my work is to {work} and I am getting {salary}')
# Out:
# My Profession is Software Devloper And my work is to Write Code and I am getting 40000

# %% [markdown]
# # How to Take input in Python

# %%
F_Name=input("Enter your First Name")
L_Name=input("Enter your Last Name")
print(f'Full name is {F_Name +" " +L_Name} ')
# Out:
# Enter your First Name
# Enter your Last Name
# Full name is

# %%
age=input("Enter your age")
print(age)
# Out:
# Enter your age 23
# 23

# %%
type(age)
# Out:
# str

# %%
age=int(input("Enter Age"))
print(f"Age is {age}")
# Out:
# Enter Age 23
# Age is 23

# %%
type(age)
# Out:
# int

# %%
Profession = input("Enter your Profession : ")
work=input("Enter your work : ")
salary=input("Enter your Salary : ")
print(f'My Profession is {Profession} And my work is to {work} and Im getting {salary} in-hand salary')
# Out:
# Enter your Profession :  gamer
# Enter your work :  Play game
# Enter your Salary :  30000
# My Profession is gamer And my work is to Play game and Im getting 30000 in-hand salary

# %%
type(salary)
# Out:
# str

# %%
Profession = input("Enter your Profession : ")
work=input("Enter your work : ")
salary=int(input("Enter your Salary : "))
print(f'My Profession is {Profession} And my work is to {work} and Im getting {salary} in-hand salary')
# Out:
# Enter your Profession :  doctor
# Enter your work :  check paitence
# Enter your Salary :  30000
# My Profession is doctor And my work is to check paitence and Im getting 30000 in-hand salary

# %%
type(salary)
# Out:
# int

# %%
weight=float(input("Enter your weight: "))
print(f'Entered Weight is {weight} Kg')
# Out:
# Enter your weight:  45.6
# Entered Weight is 45.6 Kg

# %% [markdown]
# # Multiple Variables

# %%
a,b,c=1,2,3

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %% [markdown]
# # Operatos in Phython

# %%
b=5
a=3
c=a+b
print(c)
# Out:
# 8

# %%
5/3
# Out:
# 1.6666666666666667

# %%
5//3
# Out:
# 1

# %%
5%3
# Out:
# 2

# %% [markdown]
# # Assignment Operators

# %%
a=4

# %%
a
# Out:
# 4

# %%
a +=2

# %%
a
# Out:
# 6

# %%
v=9

# %%
v
# Out:
# 9

# %%
v-=1

# %%
v
# Out:
# 8

# %%
Z=13

# %%
Z
# Out:
# 13

# %%
Z*=2

# %%
Z
# Out:
# 26

# %%
X=19

# %%
X
# Out:
# 19

# %%
X/=2

# %%
X
# Out:
# 9.5

# %%
X//=2

# %%
X
# Out:
# 4.0

# %%
Q=10
Q
# Out:
# 10

# %%
Q//=3
Q
# Out:
# 3

# %%
Q/=3
Q
# Out:
# 1.0

# %%
10//3
# Out:
# 3

# %%
10/3
# Out:
# 3.3333333333333335

# %% [markdown]
# # Comparison Operators

# %%
a=3

# %%
a
# Out:
# 3

# %%
b=2

# %%
a==b
# Out:
# False

# %%
"H"=="A"
# Out:
# False

# %%
"B"=="B"
# Out:
# True

# %%
53!=53
# Out:
# False

# %%
169!=196
# Out:
# True

# %%
69>96
# Out:
# False

# %%
93>90
# Out:
# True

# %%
55>95
# Out:
# False

# %%
56<99
# Out:
# True

# %%
653>=555
# Out:
# True

# %%
555>555
# Out:
# False

# %%
555>=555
# Out:
# True

# %%
"Hello"=="Bye"
# Out:
# False

# %%
"Tata"!="See You"
# Out:
# True

# %% [markdown]
# # Logical Operators

# %%
#And

# %%
5>2 and 99>10
# Out:
# True

# %%
#OR

# %%
3>1 or 2>4
# Out:
# True

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# # Membership Operator

# %%
 "i" in "Membership"
# Out:
# True

# %%
"z" in "Vinayak"
# Out:
# False

# %%
"I" in "Vinayak"
# Out:
# False

# %%
"Ram" in "R"
# Out:
# False

# %% [markdown]
# # Inbuilt functions

# %%
"hello".capitalize()
# Out:
# 'Hello'

# %%
"hello".count("l")
# Out:
# 2

# %%
"vinayak waikar".count(" ")
# Out:
# 1

# %%
"V".center(5)
# Out:
# '  V  '

# %%
'vina'.center(5,"*")
# Out:
# '*vina'

# %%
"Vina".center(10)
# Out:
# '   Vina   '

# %%
"Jay".center(25,"#")
# Out:
# '###########Jay###########'

# %%
"My name is Vinayak Waikar".split(" ")
# Out:
# ['My', 'name', 'is', 'Vinayak', 'Waikar']

# %%
"Hello".isdigit()
# Out:
# False

# %%
"121343559".isdigit()
# Out:
# True

# %%
"@".isalnum()
# Out:
# False

# %%
"Vinaa@23".isalnum()
# Out:
# False

# %%
"Siddhi23".isalnum()
# Out:
# True

# %%
"hello".istitle()
# Out:
# False

# %%
"Hello".istitle()
# Out:
# True

# %%
"True".islower()
# Out:
# False

# %%
"VINA".isupper()
# Out:
# True
