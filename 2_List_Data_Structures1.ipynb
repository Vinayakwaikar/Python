# %% [markdown]
# # Data Structures

# %% [markdown]
# List

# %%
Name = ["sham", "Ram", "Laxman" , "Geeta"]

# %%
Name[3]
# Out:
# 'Geeta'

# %%
Random=[1,1.4,"hello",2+3j, "$"]

# %%
Random[3]="V"

# %%
Random
# Out:
# [1, 1.4, 'hello', 'V', '$']

# %% [markdown]
# # Nested List

# %%
Ex=[1,2,[10,20,30],3,4,5]

# %%
Ex[2]
# Out:
# [10, 20, 30]

# %%
Ex[2][2]
# Out:
# 30

# %%
L1=[1,2,3,[10,20,[101,102,104,[201,202],105],50],5]

# %%
L1[3][2][0]
# Out:
# 101

# %% [markdown]
# Q) Now access 202 from L1

# %%
L1 [3][2][3][1]
# Out:
# 202

# %%
NL=[10,20,30,[101,102,[201,202],103,104],40,50,60]

# %%
NL[3][2][::-1]
# Out:
# [202, 201]

# %%
# Out:
# [10, 20, 30, [101, 102, [201, 202], 103, 104], 40, 50, 60]

# %% [markdown]
# # Applying Functions to List

# %%
a=[10,20,"hello",True]

# %%
a
# Out:
# [10, 20, 'hello', True]

# %%
a.append(101)

# %%
a
# Out:
# [10, 20, 'hello', True, 101]

# %%
a.append([201,202,203])

# %%
a
# Out:
# [10, 20, 'hello', True, 101, [201, 202, 203]]

# %% [markdown]
# Extend

# %%
a.extend("ram")

# %%
a
# Out:
# [10, 20, 'hello', True, 101, [201, 202, 203], 'r', 'a', 'm']

# %%
a.extend([501,502,503])

# %%
a
# Out:
# [10, 20, 'hello', True, 101, [201, 202, 203], 'r', 'a', 'm', 501, 502, 503]

# %%
a.extend(True)
    #it will give no output bcauz True cannot be seperated further
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 a.extend(True)
#       2     #it will give no output bcauz True cannot be seperated further
#
# TypeError: 'bool' object is not iterable

# %%
k=[1,1,2,2,2,3,3,3,3,"Hello"]

# %%
k
# Out:
# [1, 1, 2, 2, 2, 3, 3, 3, 3, 'Hello']

# %%
k.index("Hello")
# Out:
# 9

# %%
k.index(2)
# Out:
# 2

# %%
k.index(1)
# Out:
# 0

# %%
k.count(2)
# Out:
# 3

# %%
k.count(2)
# Out:
# 3

# %%
k.count("Hello")
# Out:
# 1

# %%
k.insert(2,101)

# %%
k
# Out:
# [1, 1, 101, 2, 2, 2, 3, 3, 3, 3, 'Hello']

# %%
k.remove(101)

# %%
k
# Out:
# [1, 1, 2, 2, 2, 3, 3, 3, 3, 'Hello']

# %%
k.remove(101)
k
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 k.remove(101)
#       2 k
#
# ValueError: list.remove(x): x not in list

# %%
k.pop()
# Out:
# 'Hello'

# %%
k
# Out:
# [1, 1, 2, 2, 2, 3, 3, 3, 3]

# %%
k.reverse()
k
# Out:
# [3, 3, 3, 3, 2, 2, 2, 1, 1]

# %%
c=[72,98,4,3,99,2,9,44]
c.sort()

# %% [markdown]
# # Slicing

# %%
c
# Out:
# [2, 3, 4, 9, 44, 72, 98, 99]

# %%
c[0:4]
# Out:
# [2, 3, 4, 9]

# %%
c[3:6]
# Out:
# [9, 44, 72]

# %%
c[3:7]
# Out:
# [9, 44, 72, 98]

# %%
c[2:] #empty no. indicates that till last index
# Out:
# [4, 9, 44, 72, 98, 99]

# %%
c[:5]
# Out:
# [2, 3, 4, 9, 44]

# %%
z=[10,20,30,40,50,60,70,80]

# %%
z[: : 2]
# Out:
# [10, 30, 50, 70]

# %%
z[1: : 3]
# Out:
# [20, 50, 80]

# %%
 z[4:0:-1]
# Out:
# [50, 40, 30, 20]

# %%
z[: : -2]
# Out:
# [80, 60, 40, 20]

# %%
NL=[10,20,30,[101,102,[201,203],103,104],40,50,60]

# %%
NL[0:4]
# Out:
# [10, 20, 30, [101, 102, [201, 203], 103, 104]]

# %%
NL[3]
# Out:
# [101, 102, [201, 203], 103, 104]

# %%
NL[3:2 :-1]
# Out:
# [[101, 102, [201, 203], 103, 104]]

# %%
NL[3][2:0 :-1]
# Out:
# [[201, 203], 102]

# %%
NL[4:7]
# Out:
# [40, 50, 60]

# %%
NL[7:3:-1]
# Out:
# [60, 50, 40]

# %%
NL[7:2:-1]
# Out:
# [60, 50, 40, [101, 102, [201, 203], 103, 104]]

# %%
NL[3][2::-1]
# Out:
# [[201, 203], 102, 101]

# %%
NL[3][2:1:-1]
# Out:
# [[201, 203]]

# %%
NL[: :2]
# Out:
# [10, 30, 40, 60]

# %%
NL[: : -1]
# Out:
# [60, 50, 40, [101, 102, [201, 203], 103, 104], 30, 20, 10]

# %%
NL2=[[1,2,3],[4,5,6],[7,8,9]]

# %%
NL2[1]
# Out:
# [4, 5, 6]

# %%
NL2[2][-1]
# Out:
# 9

# %%
z = [10, 20, 50, 76, 89, 56, 87, 90]

# %%
z
# Out:
# [10, 20, 50, 76, 89, 56, 87, 90]

# %%
z[-3::-1]
# Out:
# [56, 89, 76, 50, 20, 10]

# %%
# Write code to reverse only the middle three elements of a 5-element list
Q=[10,20,30,40,50]

# %%
Q[3:0:-1]
# Out:
# [40, 30, 20]

# %%
P_list=[1,2,3,4,5,6,7,8,9,0,11,12,13,14,15]
for i in P_list:
    if i%2==0:
        P_list.remove(i)    
P_list
# Out:
# [1, 3, 5, 7, 9, 11, 13, 15]
