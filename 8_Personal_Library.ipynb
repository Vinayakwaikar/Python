# %%
Library = {
    "Atomic Habits": ["James Clear", 2018, "Available"],
    "The Alchemist": ["Paulo Coelho", 1988, "Available"],
    "Rich Dad Poor Dad": ["Robert Kiyosaki", 1997, "Not Available"],
    "Ikigai": ["Hector Garcia", 2016, "Available"],
    "Deep Work": ["Cal Newport", 2016, "Not Available"],
    "Think And Grow Rich": ["Napoleon Hill", 1937, "Available"],
    "The Power Of Now": ["Eckhart Tolle", 1997, "Available"],
    "Can't Hurt Me": ["David Goggins", 2018, "Not Available"],
    "The 5 Am Club": ["Robin Sharma", 2018, "Available"],
    "Start With Why": ["Simon Sinek", 2009, "Available"],
    "Zero To One": ["Peter Thiel", 2014, "Not Available"],
    "The Subtle Art Of Not Giving A F": ["Mark Manson", 2016, "Available"],
    "How To Win Friends And Influence People": ["Dale Carnegie", 1936, "Available"],
    "The Psychology Of Money": ["Morgan Housel", 2020, "Not Available"],
    "Sapiens": ["Yuval Noah Harari", 2011, "Available"],
    "Homo Deus": ["Yuval Noah Harari", 2015, "Available"],
    "The Monk Who Sold His Ferrari": ["Robin Sharma", 1997, "Not Available"],
    "You Can Win": ["Shiv Khera", 1998, "Available"],
    "Wings Of Fire": ["Apj Abdul Kalam", 1999, "Available"],
    "The Intelligent Investor": ["Benjamin Graham", 1949, "Not Available"],
    "Elon Musk": ["Ashlee Vance", 2015, "Available"],
    "Steve Jobs": ["Walter Isaacson", 2011, "Available"],
    "Do Epic Shit": ["Ankur Warikoo", 2021, "Available"],
    "Make Your Bed": ["William Mcraven", 2017, "Not Available"],
    "The Lean Startup": ["Eric Ries", 2011, "Available"],
    "Crushing It": ["Gary Vaynerchuk", 2018, "Available"],
    "Rework": ["Jason Fried", 2010, "Not Available"],
    "The One Thing": ["Gary Keller", 2013, "Available"],
    "Grit": ["Angela Duckworth", 2016, "Available"],
    "Mindset": ["Carol Dweck", 2006, "Not Available"]
}

# %%
while True:
    print("\n1.Search by Book Name")
    print("2.Search by Author")
    print("3.Search by Year")
    print("4.Show Available Books")
    print("5.Borrow Book")
    print("6.Return Book")
    print("7.Exit")

    choice=int(input("Enter your choice"))
    
    if choice == 1:
        book_name=input("Enter the name of book")
        book_name=book_name.lower()
        if book_name in Library:
            details=Library[book_name]
            print ('\n',details)
        else:
            print("Book not availble");
            break
    elif choice == 2:
        found=False
        author_name=input("Enter name of author: ")
        for books,details in Library.items():
            if author_name.lower()==details[0].lower():
                print("\nBook Found")
                print("Book Name : ",books)
                print("Author Name : ",details[0])
                print("Year : ",details[1])
                print("Available OR Not : ",details[2])
                found=True
        if not found:
            print("Book not found")

    elif choice == 3:
        year=int(input("Enter the year"))
        found= False
        for books,details in Library.items():
            if year==details[1]:
                print("\nBook Found")
                print("Book Name : ",books)
                print("Author Name : ",details[0])
                print("Year : ",details[1])
                print("Available OR Not : ",details[2])
                found=True
        if not found:
            print("Book not found")

    elif choice == 4:
        found= False
        count=1
        index_map = {}
        print("-------------------------------------------")

        for books,details in Library.items():
            if details[2]=="Available":
                print(count,".",books)
                count=count+1
                found=True
        if not found:
            print("No Book Available")
        print("-------------------------------------------")

        
    elif choice == 5:
        book_name=input("Enter the Name of Book\n")
        found=False
        for books,details in Library.items():
            if book_name.lower()==books.lower():
                if details[2]=="Available":
                    details[2]="Not Available"
                    print("\nBook Borrowed successfully")
                    
                else:
                    print("Book Not Available at the moment")
                found=True
                break              
        if not found:
            print("Book not found,Try Again...")
    
    elif choice == 6:
        book_name=input("Enter the Name of Book to return\n")
        found=False
        for books,details in Library.items():
            if book_name.lower()==books.lower():
                if details[2]=="Not Available":
                    details[2]="Available"
                    print("\nBook Returend successfully")
                    
                else:
                    print("Book not Borrowed ,yet ")
                found=True
                break              
        if not found:
            print("Book not found,Try Again...")
        
    elif choice == 7:    
        break
    else:
        print("Invalid choice, try again")
# Out:
# 1.Search by Book Name
# 2.Search by Author
# 3.Search by Year
# 4.Show Available Books
# 5.Borrow Book
# 6.Return Book
# 7.Exit
# Enter your choice 4
# -------------------------------------------
# 1 . Atomic Habits
# 2 . The Alchemist
# 3 . Ikigai
# 4 . Think And Grow Rich
# 5 . The Power Of Now
# 6 . The 5 Am Club
# 7 . Start With Why
# 8 . The Subtle Art Of Not Giving A F
# 9 . How To Win Friends And Influence People
# 10 . Sapiens
# 11 . Homo Deus
# 12 . You Can Win
# 13 . Wings Of Fire
# 14 . Elon Musk
# 15 . Steve Jobs
# 16 . Do Epic Shit
# 17 . The Lean Startup
# 18 . Crushing It
# 19 . The One Thing
# 20 . Grit
# -------------------------------------------
#
# 1.Search by Book Name
# 2.Search by Author
# 3.Search by Year
# 4.Show Available Books
# 5.Borrow Book
# 6.Return Book
# 7.Exit
# Enter your choice 5
# Enter the Name of Book
#  Sapiens
# Book Borrowed successfully
#
# 1.Search by Book Name
# 2.Search by Author
# 3.Search by Year
# 4.Show Available Books
# ...
